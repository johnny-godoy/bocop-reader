# %%
import os
import sys



module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from bocop_solution import BOCOPSolution

# %%
jackson = BOCOPSolution("data/jackson")

# %%
jackson.states.plot();
jackson.controls.plot();
